# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import joblib

# %%
# Load your trained K-means model
kmeans = joblib.load('CR_PCR_7E.pkl')

# Load PCA model (if used for training)
# Replace 'your_pca.pkl' with the actual file path to your PCA model
pca = joblib.load('CR_PCR_7E.pkl')

# %%
cluster_crop_names = {
    0: 'rice',
    1: 'maize',
    2: 'chickpea',
    3: 'kidneybeans',
    4: 'pigeonpeas',
    5: 'mothbeans',
    6: 'mungbean',
    7: 'blackgram',
    8: 'lentil',
    9: 'pomegranate',
    10: 'banana',
    11: 'mango',
    12: 'grapes',
    13: 'watermelon',
    14: 'muskmelon',
    15: 'apple',
    16: 'orange',
    17: 'papaya',
    18: 'coconut',
    19: 'cotton',
    20: 'jute',
    21: 'coffee'
}

# %%
# Create a function to get user input
def get_user_input():
    print("Enter the following values:")
    N = float(input("N (Nitrogen content): "))
    P = float(input("P (Phosphorous content): "))
    K = float(input("K (Potassium content): "))
    temperature = float(input("Temperature (in °C): "))
    humidity = float(input("Humidity (in %): "))
    ph = float(input("pH: "))
    rainfall = float(input("Rainfall (in mm): "))
    
    # Create a DataFrame from the user input
    user_input_data = pd.DataFrame({
        'N': [N],
        'P': [P],
        'K': [K],
        'temperature': [temperature],
        'humidity': [humidity],
        'ph': [ph],
        'rainfall': [rainfall]
    })

    return user_input_data

# %%
# Predict cluster label for user input
def predict_crop():
    user_input = get_user_input()
    
    # Standardize user input data (use the same scaler as used during training)
    # If not using PCA, you can skip this step
    user_input_standardized = pca.transform(user_input)

    # Predict the cluster label
    predicted_cluster = kmeans.predict(user_input_standardized)

    # Map the cluster label to crop name (assuming you have cluster_crop_names defined)
    predicted_crop = cluster_crop_names[predicted_cluster[0]]
    
    print(f"The predicted crop is: {predicted_crop}")

# Run the prediction function
predict_crop()
# Out:
# Enter the following values:
# c:\Users\VIRAT\anaconda3\lib\site-packages\sklearn\base.py:458: UserWarning: X has feature names, but KMeans was fitted without feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19372\1638331967.py in <module>
#      16
#      17 # Run the prediction function
# ---> 18 predict_crop()
#
# ~\AppData\Local\Temp\ipykernel_19372\1638331967.py in predict_crop()
#       5     # Standardize user input data (use the same scaler as used during training)
#       6     # If not using PCA, you can skip this step
# ----> 7     user_input_standardized = pca.transform(user_input)
#       8
#       9     # Predict the cluster label
#
# c:\Users\VIRAT\anaconda3\lib\site-packages\sklearn\utils\_set_output.py in wrapped(self, X, *args, **kwargs)
#     155     @wraps(f)
#     156     def wrapped(self, X, *args, **kwargs):
# --> 157         data_to_wrap = f(self, X, *args, **kwargs)
#     158         if isinstance(data_to_wrap, tuple):
#     159             # only wrap the first output for cross decomposition
#
# c:\Users\VIRAT\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py in transform(self, X)
#    1162         check_is_fitted(self)
#    1163
# -> 1164         X = self._check_test_data(X)
#    1165         return self._transform(X)
#    1166
#
# c:\Users\VIRAT\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py in _check_test_data(self, X)
#     948
#     949     def _check_test_data(self, X):
# --> 950         X = self._validate_data(
#     951             X,
#     952             accept_sparse="csr",
#
# c:\Users\VIRAT\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     624
#     625         if not no_val_X and check_params.get("ensure_2d", True):
# --> 626             self._check_n_features(X, reset=reset)
#     627
#     628         return out
#
# c:\Users\VIRAT\anaconda3\lib\site-packages\sklearn\base.py in _check_n_features(self, X, reset)
#     413
#     414         if n_features != self.n_features_in_:
# --> 415             raise ValueError(
#     416                 f"X has {n_features} features, but {self.__class__.__name__} "
#     417                 f"is expecting {self.n_features_in_} features as input."
#
# ValueError: X has 7 features, but KMeans is expecting 2 features as input.
